# %% [markdown]
# <center> <h1> Diagnose Latent Cytomegalovirus Using CyTOF Data and Deep Learning <h1> </center>
#
# <center>Zicheng Hu, Ph.D.</center>
# <center>Research Scientist</center>
# <center>ImmPort Team</center>
# <center>The Unversity of California, San Francisco</center>
#
# ![alt text](Data/header.png)

# %% [markdown]
# ### Introduction
# A deep neural network (a.k.a. deep learning) is an artificial neural network with multiple layers between the input and output layers. It was proven to be highly effective for a variety of predictive tasks. In health care, deep learning is quickly gaining popularity and has been implemented for applications such as image-based diagnosis and personalized drug recommendations. In this tutorial, we will build a tailored deep-learning model for CyTOF data to diagnosis latent Cytomegalovirus infection using Keras and TensorFlow. To run this tutorial, download the [github repository](https://github.com/hzc363/DeepLearningCyTOF) and run the [jupyter notebook](https://github.com/hzc363/DeepLearningCyTOF/blob/master/DeepLearning_CyTOF.ipynb).

# %% [markdown]
# ### Step 1: Import Functions
# Before we start, we first import functions that we will use in this tutorial from different libraries.

# %%
##### Step 1: import functions #####
from keras.layers import Dense, Flatten, BatchNormalization, Activation, Conv2D, AveragePooling2D, Input
from keras.models import load_model, Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import backend as K
import pickle
import pandas as pd
import numpy as np
from numpy.random import seed; seed(111)
import random
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import set_random_seed; set_random_seed(111)
from sklearn.metrics import roc_curve, auc
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz, DecisionTreeRegressor
from scipy.stats import ttest_ind
from IPython.display import Image  
import pydotplus
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %% [markdown]
# ### Step 2: Load data
#
# We load the data, which are stored in the "allData.obj" file. The data includes three parts, meta-data, CyTOF data, and marker names.
#
# * The **CyTOF data** contains the single-cell profile of 27 markers. For the convenience of this tutorial, we already downloaded the fcs files from ImmPort and preprocessed the data into Numpy arrays. See [an example](https://github.com/hzc363/DeepLearningCyTOF/tree/master/FCS_to_Array) for the preprocessing of the FCS files. The dimension of the Numpy array is 472 samples x 10000 cells x 27 markers.
# * The **metadata** contains the sample level information, including the study accession number for each sample and the ground truth of CMV infection. It is stored as a pandas data frame.
# * The **marker names** contain the name of the 27 markers.

# %%
##### Step 2: load data #####

#Download data
tutorial_files = ! ls Data
if "allData.obj" not in tutorial_files:
    print("Downloading Data:")
    ! wget https://storage.googleapis.com/deep_learning_cytof/allData.obj -P ./Data
        
#load data
allData = pickle.load( open( "Data/allData.obj", "rb" ) )
metaData = allData["metaData"]
cytoData = allData["cytoData"]
markerNames = allData["markerNames"]

# inspect the data
print("\nFirst 5 rows of metaData: ")
print(metaData.head(),"\n")

print("Dimensions of cytoData: ",cytoData.shape,"\n")
print("Names of the 27 makers: \n",markerNames.values)
# Out:
# First 5 rows of metaData:
#                                                  name study_accession  CMV_Ab
# 0   011514-Mike-Study 21-2011-plate 1-2100101_cell...          SDY113    True
# 1   011514-Mike-Study 21-2011-plate 1-2100201_cell...          SDY113    True
# 3   011514-Mike-Study 21-2011-plate 1-2100501_cell...          SDY113    True
# 6   011514-Mike-Study 21-2011-plate 1-2100901_cell...          SDY113   False
# 19  011514-Mike-Study 21-2011-plate 1-2102501_cell...          SDY113   False
#
# Dimensions of cytoData:  (472, 10000, 27, 1)
#
# Names of the 27 makers:
#  ['VIABILITY' 'TCRGD' 'IGD' 'HLADR' 'DNA2' 'DNA1' 'CELL_LENGTH' 'CD94'
#  'CD85J' 'CD8' 'CD56' 'CD45RA' 'CD4' 'CD38' 'CD33' 'CD3' 'CD28' 'CD27'
#  'CD25' 'CD24' 'CD20' 'CD19' 'CD161' 'CD16' 'CD14' 'CD127' 'CCR7']

# %% [markdown]
# ### Step 3: Split data into training, validation and testing sets
# Now, lets split the data into training, validation, and testing sets. The training data is used to train the deep learning model. The validation dataset is used to select the best parameters for the model and to avoid overfitting. The test dataset is used to evaluate the performance of the final model.
#
# The CyTOF dataset contains samples from 9 studies available on ImmPort. We will use samples from the study SDY515 as a validation set, samples from the study SDY519 as a testing set, and the rest of the samples as a training set.

# %%
##### Step 3: split train, validation and test######
y = metaData.CMV_Ab.values
x = cytoData

train_id = (metaData.study_accession.isin(["SDY515","SDY519"])==False)
valid_id = metaData.study_accession=="SDY515"
test_id = metaData.study_accession =="SDY519"

x_train = x[train_id]; y_train = y[train_id]
x_valid = x[valid_id]; y_valid = y[valid_id]
x_test = x[test_id]; y_test = y[test_id]

# %% [markdown]
# ### Step 4: Define the deep learning model
# We will use a customized convolution neural network (CNN) to analyze the CyTOF data. For each sample, the CyTOF data is a matrix with rows as cells and columns as markers. It is crucial to notice that the CyTOF data is an unordered collection of cells (rows). For example, both matrix 1 and matrix 2 profiles the same sample in Figure 1A, even though they have different orders of rows.
#
# ![alt text](Data/Figure1.png)
#
#
# Based on the characteristics of the CyTOF data, we design a CNN model that is invariant to the permutation of rows. The model contains six layers: input layer, first and second convolution layer, pooling layer, dense layer, and output layer.
#
# * The **input layer** receives the CyTOF data matrix.
#
# * The **first convolution layer** uses three filters to scan each row of the CyTOF data. This layer extracts relevant information from the cell marker profile of each cell.
#
# * The **second convolution layer** uses three filters to scan each row of the first layer's output. Each filter combines information from the first layer for each cell.
#
# * The **pooling layers** averages the outputs of the second convolution layer. The purpose is to aggregate the cell level information into sample-level information.
#
# * The **dense layer** further extracts information from the pooling layer.
#
# * The **output layer** uses logistic regression to report the probability of CMV infection for each sample.

# %%
##### Step 4: define model #####

# input
model_input = Input(shape=x_train[0].shape)

# first convolution layer
model_output = Conv2D(3, kernel_size=(1, x_train.shape[2]),
                 activation=None)(model_input)
model_output = BatchNormalization()(model_output)
model_output = Activation("relu")(model_output)

# sceond convolution layer
model_output = Conv2D(3, (1, 1), activation=None)(model_output)
model_output = BatchNormalization()(model_output)
model_output = Activation("relu")(model_output)

# pooling layer
model_output = AveragePooling2D(pool_size=(x_train.shape[1], 1))(model_output)
model_output = Flatten()(model_output)

# Dense layer
model_output = Dense(3, activation=None)(model_output)
model_output = BatchNormalization()(model_output)
model_output = Activation("relu")(model_output)

# output layer
model_output = Dense(1, activation=None)(model_output)
model_output = BatchNormalization()(model_output)
model_output = Activation("sigmoid")(model_output)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Step 5: Fit the model
# In this step, we will use the training data to fit the model. We will use the Adam algorithm, which is an extension of the gradient descent method to train our model. Adam algorithm will search the model space step by step (epochs) until the optimal model is identified. At each step, we will use validation data to evaluate the performance of the model. The best model will be saved.

# %%
##### Step 5: Fit model #####

# specify input and output
model = Model(inputs=[model_input],
              outputs=model_output)

# define loss function and optimizer
model.compile(loss='binary_crossentropy',
              optimizer=Adam(lr=0.0001),
              metrics=['accuracy'])

# save the best performing model
checkpointer = ModelCheckpoint(filepath='Result/saved_weights.hdf5', 
                               monitor='val_loss', verbose=0, 
                               save_best_only=True)

# model training
model.fit([x_train], y_train,
          batch_size=60,
          epochs=500, 
          verbose=1,
          callbacks=[checkpointer],
          validation_data=([x_valid], y_valid))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 333 samples, validate on 79 samples
# Epoch 1/500
# 333/333 [==============================] - 2s 6ms/step - loss: 0.8607 - acc: 0.4595 - val_loss: 0.7309 - val_acc: 0.5443
# Epoch 2/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8600 - acc: 0.4505 - val_loss: 0.7332 - val_acc: 0.5443
# Epoch 3/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8595 - acc: 0.4685 - val_loss: 0.7328 - val_acc: 0.5443
# Epoch 4/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8469 - acc: 0.4835 - val_loss: 0.7342 - val_acc: 0.5316
# Epoch 5/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8484 - acc: 0.4715 - val_loss: 0.7347 - val_acc: 0.5190
# Epoch 6/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8520 - acc: 0.4655 - val_loss: 0.7371 - val_acc: 0.5063
# Epoch 7/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8294 - acc: 0.4925 - val_loss: 0.7394 - val_acc: 0.5190
# Epoch 8/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8392 - acc: 0.4895 - val_loss: 0.7403 - val_acc: 0.5063
# Epoch 9/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8523 - acc: 0.4925 - val_loss: 0.7420 - val_acc: 0.5190
# Epoch 10/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8485 - acc: 0.4715 - val_loss: 0.7443 - val_acc: 0.5190
# Epoch 11/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8392 - acc: 0.4745 - val_loss: 0.7462 - val_acc: 0.5316
# Epoch 12/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8430 - acc: 0.4835 - val_loss: 0.7485 - val_acc: 0.5190
# Epoch 13/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8382 - acc: 0.5045 - val_loss: 0.7507 - val_acc: 0.5190
# Epoch 14/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8386 - acc: 0.4865 - val_loss: 0.7519 - val_acc: 0.5190
# Epoch 15/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8340 - acc: 0.4895 - val_loss: 0.7526 - val_acc: 0.5190
# Epoch 16/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8356 - acc: 0.4895 - val_loss: 0.7534 - val_acc: 0.5190
# Epoch 17/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8341 - acc: 0.4805 - val_loss: 0.7538 - val_acc: 0.5063
# Epoch 18/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8198 - acc: 0.4925 - val_loss: 0.7549 - val_acc: 0.5063
# Epoch 19/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8301 - acc: 0.4835 - val_loss: 0.7567 - val_acc: 0.5063
# Epoch 20/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8308 - acc: 0.4835 - val_loss: 0.7590 - val_acc: 0.4937
# Epoch 21/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8249 - acc: 0.4835 - val_loss: 0.7610 - val_acc: 0.4937
# Epoch 22/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8214 - acc: 0.4985 - val_loss: 0.7632 - val_acc: 0.5063
# Epoch 23/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8234 - acc: 0.4805 - val_loss: 0.7655 - val_acc: 0.4810
# Epoch 24/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8238 - acc: 0.4895 - val_loss: 0.7687 - val_acc: 0.4810
# Epoch 25/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8152 - acc: 0.5075 - val_loss: 0.7707 - val_acc: 0.4684
# Epoch 26/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8095 - acc: 0.4925 - val_loss: 0.7717 - val_acc: 0.4684
# Epoch 27/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8078 - acc: 0.5135 - val_loss: 0.7742 - val_acc: 0.4557
# Epoch 28/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8202 - acc: 0.4805 - val_loss: 0.7761 - val_acc: 0.4557
# Epoch 29/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8066 - acc: 0.5165 - val_loss: 0.7791 - val_acc: 0.4557
# Epoch 30/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8087 - acc: 0.4895 - val_loss: 0.7821 - val_acc: 0.4557
# Epoch 31/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8060 - acc: 0.5045 - val_loss: 0.7869 - val_acc: 0.4557
# Epoch 32/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7979 - acc: 0.5315 - val_loss: 0.7905 - val_acc: 0.4430
# Epoch 33/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7881 - acc: 0.5255 - val_loss: 0.7944 - val_acc: 0.4557
# Epoch 34/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7973 - acc: 0.5255 - val_loss: 0.7980 - val_acc: 0.4557
# Epoch 35/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8018 - acc: 0.5255 - val_loss: 0.8017 - val_acc: 0.4557
# Epoch 36/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8038 - acc: 0.5315 - val_loss: 0.8059 - val_acc: 0.4430
# Epoch 37/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7920 - acc: 0.5315 - val_loss: 0.8102 - val_acc: 0.4304
# Epoch 38/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.8114 - acc: 0.4955 - val_loss: 0.8168 - val_acc: 0.4304
# Epoch 39/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7930 - acc: 0.5255 - val_loss: 0.8226 - val_acc: 0.4430
# Epoch 40/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7965 - acc: 0.5165 - val_loss: 0.8264 - val_acc: 0.4304
# Epoch 41/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7913 - acc: 0.5345 - val_loss: 0.8315 - val_acc: 0.4430
# Epoch 42/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7858 - acc: 0.5225 - val_loss: 0.8354 - val_acc: 0.4684
# Epoch 43/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7967 - acc: 0.5045 - val_loss: 0.8411 - val_acc: 0.4684
# Epoch 44/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7790 - acc: 0.5435 - val_loss: 0.8476 - val_acc: 0.4684
# Epoch 45/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7816 - acc: 0.5195 - val_loss: 0.8539 - val_acc: 0.4557
# Epoch 46/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7823 - acc: 0.5195 - val_loss: 0.8601 - val_acc: 0.4810
# Epoch 47/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7798 - acc: 0.5285 - val_loss: 0.8673 - val_acc: 0.4810
# Epoch 48/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7769 - acc: 0.5255 - val_loss: 0.8734 - val_acc: 0.4684
# Epoch 49/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7661 - acc: 0.5285 - val_loss: 0.8781 - val_acc: 0.4684
# Epoch 50/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7699 - acc: 0.5435 - val_loss: 0.8846 - val_acc: 0.4684
# Epoch 51/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7714 - acc: 0.5285 - val_loss: 0.8932 - val_acc: 0.4810
# Epoch 52/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7716 - acc: 0.5465 - val_loss: 0.8988 - val_acc: 0.4810
# Epoch 53/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7602 - acc: 0.5556 - val_loss: 0.9045 - val_acc: 0.4810
# Epoch 54/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7627 - acc: 0.5285 - val_loss: 0.9104 - val_acc: 0.4810
# Epoch 55/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7468 - acc: 0.5435 - val_loss: 0.9154 - val_acc: 0.4810
# Epoch 56/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7622 - acc: 0.5195 - val_loss: 0.9214 - val_acc: 0.4810
# Epoch 57/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7598 - acc: 0.5495 - val_loss: 0.9258 - val_acc: 0.4810
# Epoch 58/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7569 - acc: 0.5465 - val_loss: 0.9353 - val_acc: 0.4937
# Epoch 59/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7461 - acc: 0.5646 - val_loss: 0.9432 - val_acc: 0.4937
# Epoch 60/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7477 - acc: 0.5616 - val_loss: 0.9510 - val_acc: 0.4684
# Epoch 61/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7477 - acc: 0.5255 - val_loss: 0.9599 - val_acc: 0.4557
# Epoch 62/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7403 - acc: 0.5526 - val_loss: 0.9682 - val_acc: 0.4557
# Epoch 63/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7405 - acc: 0.5616 - val_loss: 0.9762 - val_acc: 0.4557
# Epoch 64/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7389 - acc: 0.5586 - val_loss: 0.9842 - val_acc: 0.4557
# Epoch 65/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7298 - acc: 0.5706 - val_loss: 0.9933 - val_acc: 0.4557
# Epoch 66/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7340 - acc: 0.5465 - val_loss: 1.0037 - val_acc: 0.4430
# Epoch 67/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7364 - acc: 0.5556 - val_loss: 1.0077 - val_acc: 0.4430
# Epoch 68/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7298 - acc: 0.5676 - val_loss: 1.0101 - val_acc: 0.4557
# Epoch 69/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7309 - acc: 0.5465 - val_loss: 1.0128 - val_acc: 0.4304
# Epoch 70/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7300 - acc: 0.5556 - val_loss: 1.0191 - val_acc: 0.4430
# Epoch 71/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7235 - acc: 0.5495 - val_loss: 1.0238 - val_acc: 0.4430
# Epoch 72/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7323 - acc: 0.5736 - val_loss: 1.0269 - val_acc: 0.4430
# Epoch 73/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7196 - acc: 0.5676 - val_loss: 1.0302 - val_acc: 0.4304
# Epoch 74/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7167 - acc: 0.5676 - val_loss: 1.0346 - val_acc: 0.4304
# Epoch 75/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7236 - acc: 0.5736 - val_loss: 1.0408 - val_acc: 0.4304
# Epoch 76/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7028 - acc: 0.5796 - val_loss: 1.0465 - val_acc: 0.4430
# Epoch 77/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7199 - acc: 0.5886 - val_loss: 1.0560 - val_acc: 0.4557
# Epoch 78/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7052 - acc: 0.5856 - val_loss: 1.0608 - val_acc: 0.4557
# Epoch 79/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7170 - acc: 0.5796 - val_loss: 1.0624 - val_acc: 0.4557
# Epoch 80/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7113 - acc: 0.5796 - val_loss: 1.0634 - val_acc: 0.4557
# Epoch 81/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7158 - acc: 0.5796 - val_loss: 1.0674 - val_acc: 0.4557
# Epoch 82/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7020 - acc: 0.5826 - val_loss: 1.0718 - val_acc: 0.4557
# Epoch 83/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7037 - acc: 0.5886 - val_loss: 1.0749 - val_acc: 0.4430
# Epoch 84/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6995 - acc: 0.5916 - val_loss: 1.0761 - val_acc: 0.4430
# Epoch 85/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7080 - acc: 0.5736 - val_loss: 1.0785 - val_acc: 0.4304
# Epoch 86/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6938 - acc: 0.6066 - val_loss: 1.0813 - val_acc: 0.4177
# Epoch 87/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.7079 - acc: 0.5706 - val_loss: 1.0820 - val_acc: 0.4177
# Epoch 88/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6905 - acc: 0.5976 - val_loss: 1.0803 - val_acc: 0.4304
# Epoch 89/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6975 - acc: 0.5826 - val_loss: 1.0786 - val_acc: 0.4430
# Epoch 90/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6900 - acc: 0.6096 - val_loss: 1.0783 - val_acc: 0.4304
# Epoch 91/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6925 - acc: 0.5976 - val_loss: 1.0780 - val_acc: 0.4304
# Epoch 92/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6914 - acc: 0.5736 - val_loss: 1.0795 - val_acc: 0.4304
# Epoch 93/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6929 - acc: 0.5946 - val_loss: 1.0754 - val_acc: 0.4430
# Epoch 94/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6884 - acc: 0.5826 - val_loss: 1.0746 - val_acc: 0.4430
# Epoch 95/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6792 - acc: 0.6246 - val_loss: 1.0729 - val_acc: 0.4430
# Epoch 96/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6869 - acc: 0.6066 - val_loss: 1.0715 - val_acc: 0.4430
# Epoch 97/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6808 - acc: 0.5976 - val_loss: 1.0667 - val_acc: 0.4430
# Epoch 98/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6778 - acc: 0.5946 - val_loss: 1.0664 - val_acc: 0.4430
# Epoch 99/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6747 - acc: 0.5736 - val_loss: 1.0663 - val_acc: 0.4430
# Epoch 100/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6764 - acc: 0.6006 - val_loss: 1.0622 - val_acc: 0.4430
# Epoch 101/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6763 - acc: 0.6006 - val_loss: 1.0597 - val_acc: 0.4430
# Epoch 102/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6644 - acc: 0.6126 - val_loss: 1.0594 - val_acc: 0.4304
# Epoch 103/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6862 - acc: 0.5916 - val_loss: 1.0575 - val_acc: 0.4304
# Epoch 104/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6729 - acc: 0.5916 - val_loss: 1.0528 - val_acc: 0.4304
# Epoch 105/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6726 - acc: 0.5946 - val_loss: 1.0475 - val_acc: 0.4304
# Epoch 106/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6642 - acc: 0.6066 - val_loss: 1.0455 - val_acc: 0.4304
# Epoch 107/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6661 - acc: 0.6126 - val_loss: 1.0371 - val_acc: 0.4304
# Epoch 108/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6635 - acc: 0.6246 - val_loss: 1.0315 - val_acc: 0.4304
# Epoch 109/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6808 - acc: 0.5976 - val_loss: 1.0275 - val_acc: 0.4304
# Epoch 110/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6638 - acc: 0.6186 - val_loss: 1.0222 - val_acc: 0.4304
# Epoch 111/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6608 - acc: 0.6336 - val_loss: 1.0158 - val_acc: 0.4177
# Epoch 112/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6619 - acc: 0.6336 - val_loss: 1.0106 - val_acc: 0.4177
# Epoch 113/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6538 - acc: 0.6036 - val_loss: 1.0043 - val_acc: 0.4051
# Epoch 114/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6597 - acc: 0.6156 - val_loss: 1.0004 - val_acc: 0.4051
# Epoch 115/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6491 - acc: 0.6156 - val_loss: 0.9980 - val_acc: 0.4177
# Epoch 116/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6602 - acc: 0.6276 - val_loss: 0.9924 - val_acc: 0.4177
# Epoch 117/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6559 - acc: 0.6486 - val_loss: 0.9853 - val_acc: 0.4304
# Epoch 118/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6580 - acc: 0.6126 - val_loss: 0.9800 - val_acc: 0.4304
# Epoch 119/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6526 - acc: 0.6096 - val_loss: 0.9738 - val_acc: 0.4304
# Epoch 120/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6480 - acc: 0.6216 - val_loss: 0.9693 - val_acc: 0.4304
# Epoch 121/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6439 - acc: 0.6246 - val_loss: 0.9654 - val_acc: 0.4304
# Epoch 122/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6426 - acc: 0.6276 - val_loss: 0.9572 - val_acc: 0.4177
# Epoch 123/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6464 - acc: 0.6306 - val_loss: 0.9483 - val_acc: 0.4177
# Epoch 124/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6487 - acc: 0.6186 - val_loss: 0.9398 - val_acc: 0.3924
# Epoch 125/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6471 - acc: 0.6156 - val_loss: 0.9343 - val_acc: 0.3924
# Epoch 126/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6482 - acc: 0.6126 - val_loss: 0.9283 - val_acc: 0.3797
# Epoch 127/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6470 - acc: 0.6216 - val_loss: 0.9244 - val_acc: 0.3797
# Epoch 128/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6343 - acc: 0.6306 - val_loss: 0.9235 - val_acc: 0.3797
# Epoch 129/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6356 - acc: 0.6517 - val_loss: 0.9233 - val_acc: 0.3797
# Epoch 130/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6467 - acc: 0.6517 - val_loss: 0.9229 - val_acc: 0.3797
# Epoch 131/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6348 - acc: 0.6186 - val_loss: 0.9193 - val_acc: 0.3797
# Epoch 132/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6315 - acc: 0.6246 - val_loss: 0.9137 - val_acc: 0.3924
# Epoch 133/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6270 - acc: 0.6396 - val_loss: 0.9091 - val_acc: 0.3924
# Epoch 134/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6492 - acc: 0.6156 - val_loss: 0.9072 - val_acc: 0.3924
# Epoch 135/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6368 - acc: 0.6396 - val_loss: 0.9033 - val_acc: 0.3924
# Epoch 136/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6320 - acc: 0.6396 - val_loss: 0.8987 - val_acc: 0.3924
# Epoch 137/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6410 - acc: 0.6336 - val_loss: 0.8917 - val_acc: 0.3924
# Epoch 138/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6251 - acc: 0.6637 - val_loss: 0.8872 - val_acc: 0.3924
# Epoch 139/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6299 - acc: 0.6486 - val_loss: 0.8853 - val_acc: 0.3924
# Epoch 140/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6166 - acc: 0.6727 - val_loss: 0.8805 - val_acc: 0.4051
# Epoch 141/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6315 - acc: 0.6426 - val_loss: 0.8763 - val_acc: 0.4177
# Epoch 142/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6260 - acc: 0.6547 - val_loss: 0.8719 - val_acc: 0.4051
# Epoch 143/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6341 - acc: 0.6276 - val_loss: 0.8674 - val_acc: 0.4051
# Epoch 144/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6264 - acc: 0.6486 - val_loss: 0.8643 - val_acc: 0.4051
# Epoch 145/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6191 - acc: 0.6637 - val_loss: 0.8615 - val_acc: 0.4051
# Epoch 146/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6180 - acc: 0.6486 - val_loss: 0.8618 - val_acc: 0.4051
# Epoch 147/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6167 - acc: 0.6486 - val_loss: 0.8618 - val_acc: 0.3924
# Epoch 148/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6130 - acc: 0.6697 - val_loss: 0.8602 - val_acc: 0.3924
# Epoch 149/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6118 - acc: 0.6577 - val_loss: 0.8590 - val_acc: 0.3924
# Epoch 150/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6073 - acc: 0.6637 - val_loss: 0.8549 - val_acc: 0.3924
# Epoch 151/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6168 - acc: 0.6787 - val_loss: 0.8518 - val_acc: 0.3924
# Epoch 152/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6158 - acc: 0.6577 - val_loss: 0.8504 - val_acc: 0.3924
# Epoch 153/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6016 - acc: 0.6607 - val_loss: 0.8454 - val_acc: 0.4304
# Epoch 154/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6105 - acc: 0.6877 - val_loss: 0.8406 - val_acc: 0.4304
# Epoch 155/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6171 - acc: 0.6577 - val_loss: 0.8383 - val_acc: 0.4430
# Epoch 156/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6127 - acc: 0.6577 - val_loss: 0.8371 - val_acc: 0.4430
# Epoch 157/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6150 - acc: 0.6577 - val_loss: 0.8363 - val_acc: 0.4430
# Epoch 158/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6292 - acc: 0.6336 - val_loss: 0.8355 - val_acc: 0.4430
# Epoch 159/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6047 - acc: 0.6517 - val_loss: 0.8355 - val_acc: 0.4430
# Epoch 160/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6157 - acc: 0.6637 - val_loss: 0.8335 - val_acc: 0.4430
# Epoch 161/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6115 - acc: 0.6517 - val_loss: 0.8351 - val_acc: 0.4430
# Epoch 162/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6117 - acc: 0.6607 - val_loss: 0.8348 - val_acc: 0.4430
# Epoch 163/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5990 - acc: 0.6757 - val_loss: 0.8337 - val_acc: 0.4430
# Epoch 164/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6123 - acc: 0.6697 - val_loss: 0.8325 - val_acc: 0.4557
# Epoch 165/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6078 - acc: 0.6907 - val_loss: 0.8312 - val_acc: 0.4557
# Epoch 166/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6034 - acc: 0.6607 - val_loss: 0.8306 - val_acc: 0.4557
# Epoch 167/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6023 - acc: 0.6667 - val_loss: 0.8293 - val_acc: 0.4557
# Epoch 168/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5967 - acc: 0.6667 - val_loss: 0.8296 - val_acc: 0.4557
# Epoch 169/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5863 - acc: 0.6877 - val_loss: 0.8291 - val_acc: 0.4557
# Epoch 170/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6068 - acc: 0.6517 - val_loss: 0.8294 - val_acc: 0.4557
# Epoch 171/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6005 - acc: 0.6667 - val_loss: 0.8287 - val_acc: 0.4557
# Epoch 172/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5958 - acc: 0.6456 - val_loss: 0.8297 - val_acc: 0.4557
# Epoch 173/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5958 - acc: 0.6817 - val_loss: 0.8303 - val_acc: 0.4557
# Epoch 174/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5948 - acc: 0.6727 - val_loss: 0.8308 - val_acc: 0.4430
# Epoch 175/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5950 - acc: 0.6817 - val_loss: 0.8319 - val_acc: 0.4430
# Epoch 176/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5832 - acc: 0.6907 - val_loss: 0.8315 - val_acc: 0.4430
# Epoch 177/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5993 - acc: 0.6937 - val_loss: 0.8315 - val_acc: 0.4430
# Epoch 178/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5934 - acc: 0.6727 - val_loss: 0.8321 - val_acc: 0.4430
# Epoch 179/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5929 - acc: 0.6757 - val_loss: 0.8327 - val_acc: 0.4430
# Epoch 180/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.6024 - acc: 0.6456 - val_loss: 0.8353 - val_acc: 0.4430
# Epoch 181/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.6101 - acc: 0.6607 - val_loss: 0.8348 - val_acc: 0.4430
# Epoch 182/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5907 - acc: 0.6847 - val_loss: 0.8374 - val_acc: 0.4430
# Epoch 183/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5949 - acc: 0.6877 - val_loss: 0.8396 - val_acc: 0.4304
# Epoch 184/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5911 - acc: 0.6667 - val_loss: 0.8414 - val_acc: 0.4304
# Epoch 185/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5940 - acc: 0.6607 - val_loss: 0.8440 - val_acc: 0.4304
# Epoch 186/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5942 - acc: 0.6607 - val_loss: 0.8430 - val_acc: 0.4304
# Epoch 187/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5925 - acc: 0.6907 - val_loss: 0.8417 - val_acc: 0.4304
# Epoch 188/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5874 - acc: 0.6907 - val_loss: 0.8420 - val_acc: 0.4304
# Epoch 189/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5891 - acc: 0.6847 - val_loss: 0.8428 - val_acc: 0.4304
# Epoch 190/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5934 - acc: 0.6757 - val_loss: 0.8440 - val_acc: 0.4430
# Epoch 191/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5865 - acc: 0.6877 - val_loss: 0.8445 - val_acc: 0.4430
# Epoch 192/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5883 - acc: 0.6577 - val_loss: 0.8443 - val_acc: 0.4430
# Epoch 193/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5786 - acc: 0.6907 - val_loss: 0.8443 - val_acc: 0.4430
# Epoch 194/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5852 - acc: 0.6907 - val_loss: 0.8418 - val_acc: 0.4430
# Epoch 195/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5851 - acc: 0.6877 - val_loss: 0.8415 - val_acc: 0.4430
# Epoch 196/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5803 - acc: 0.7057 - val_loss: 0.8402 - val_acc: 0.4430
# Epoch 197/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5824 - acc: 0.6787 - val_loss: 0.8387 - val_acc: 0.4430
# Epoch 198/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5925 - acc: 0.6637 - val_loss: 0.8366 - val_acc: 0.4430
# Epoch 199/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5813 - acc: 0.6907 - val_loss: 0.8350 - val_acc: 0.4430
# Epoch 200/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5837 - acc: 0.6817 - val_loss: 0.8333 - val_acc: 0.4430
# Epoch 201/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5836 - acc: 0.6757 - val_loss: 0.8321 - val_acc: 0.4430
# Epoch 202/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5812 - acc: 0.7027 - val_loss: 0.8343 - val_acc: 0.4430
# Epoch 203/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5756 - acc: 0.7027 - val_loss: 0.8340 - val_acc: 0.4430
# Epoch 204/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5737 - acc: 0.6937 - val_loss: 0.8348 - val_acc: 0.4430
# Epoch 205/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5812 - acc: 0.6997 - val_loss: 0.8346 - val_acc: 0.4557
# Epoch 206/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5738 - acc: 0.6847 - val_loss: 0.8338 - val_acc: 0.4557
# Epoch 207/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5773 - acc: 0.7057 - val_loss: 0.8328 - val_acc: 0.4557
# Epoch 208/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5746 - acc: 0.7027 - val_loss: 0.8302 - val_acc: 0.4557
# Epoch 209/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5706 - acc: 0.6937 - val_loss: 0.8279 - val_acc: 0.4684
# Epoch 210/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5691 - acc: 0.7027 - val_loss: 0.8260 - val_acc: 0.4557
# Epoch 211/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5676 - acc: 0.6967 - val_loss: 0.8232 - val_acc: 0.4557
# Epoch 212/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5749 - acc: 0.6817 - val_loss: 0.8206 - val_acc: 0.4557
# Epoch 213/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5697 - acc: 0.7177 - val_loss: 0.8212 - val_acc: 0.4557
# Epoch 214/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5749 - acc: 0.7027 - val_loss: 0.8213 - val_acc: 0.4810
# Epoch 215/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5641 - acc: 0.6877 - val_loss: 0.8227 - val_acc: 0.4810
# Epoch 216/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5581 - acc: 0.7117 - val_loss: 0.8235 - val_acc: 0.4810
# Epoch 217/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5657 - acc: 0.7057 - val_loss: 0.8205 - val_acc: 0.4810
# Epoch 218/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5761 - acc: 0.6847 - val_loss: 0.8182 - val_acc: 0.4810
# Epoch 219/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5740 - acc: 0.7267 - val_loss: 0.8174 - val_acc: 0.4937
# Epoch 220/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5817 - acc: 0.6847 - val_loss: 0.8157 - val_acc: 0.4937
# Epoch 221/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5598 - acc: 0.7147 - val_loss: 0.8128 - val_acc: 0.4937
# Epoch 222/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5724 - acc: 0.6967 - val_loss: 0.8115 - val_acc: 0.5063
# Epoch 223/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5702 - acc: 0.6907 - val_loss: 0.8115 - val_acc: 0.5063
# Epoch 224/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5622 - acc: 0.6997 - val_loss: 0.8100 - val_acc: 0.5063
# Epoch 225/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5701 - acc: 0.6997 - val_loss: 0.8077 - val_acc: 0.5063
# Epoch 226/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5637 - acc: 0.7027 - val_loss: 0.8058 - val_acc: 0.5063
# Epoch 227/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5681 - acc: 0.6817 - val_loss: 0.8061 - val_acc: 0.4937
# Epoch 228/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5686 - acc: 0.7027 - val_loss: 0.8030 - val_acc: 0.5063
# Epoch 229/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5619 - acc: 0.7177 - val_loss: 0.8013 - val_acc: 0.5190
# Epoch 230/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5734 - acc: 0.6907 - val_loss: 0.7972 - val_acc: 0.5190
# Epoch 231/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5624 - acc: 0.7057 - val_loss: 0.7944 - val_acc: 0.5063
# Epoch 232/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5680 - acc: 0.6937 - val_loss: 0.7926 - val_acc: 0.5063
# Epoch 233/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5599 - acc: 0.7057 - val_loss: 0.7905 - val_acc: 0.5190
# Epoch 234/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5518 - acc: 0.7237 - val_loss: 0.7883 - val_acc: 0.5190
# Epoch 235/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5650 - acc: 0.6967 - val_loss: 0.7874 - val_acc: 0.5190
# Epoch 236/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5740 - acc: 0.6877 - val_loss: 0.7872 - val_acc: 0.5190
# Epoch 237/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5606 - acc: 0.7057 - val_loss: 0.7859 - val_acc: 0.5190
# Epoch 238/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5571 - acc: 0.7087 - val_loss: 0.7848 - val_acc: 0.5190
# Epoch 239/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5632 - acc: 0.6997 - val_loss: 0.7819 - val_acc: 0.5190
# Epoch 240/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5644 - acc: 0.7087 - val_loss: 0.7789 - val_acc: 0.5316
# Epoch 241/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5545 - acc: 0.7177 - val_loss: 0.7777 - val_acc: 0.5316
# Epoch 242/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5513 - acc: 0.7147 - val_loss: 0.7753 - val_acc: 0.5443
# Epoch 243/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5565 - acc: 0.6937 - val_loss: 0.7734 - val_acc: 0.5443
# Epoch 244/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5620 - acc: 0.7117 - val_loss: 0.7727 - val_acc: 0.5443
# Epoch 245/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5599 - acc: 0.7117 - val_loss: 0.7720 - val_acc: 0.5443
# Epoch 246/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5588 - acc: 0.6907 - val_loss: 0.7719 - val_acc: 0.5443
# Epoch 247/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5540 - acc: 0.7207 - val_loss: 0.7709 - val_acc: 0.5443
# Epoch 248/500
# 333/333 [==============================] - 1s 3ms/step - loss: 0.5451 - acc: 0.7327 - val_loss: 0.7717 - val_acc: 0.5443
# Epoch 249/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5624 - acc: 0.7147 - val_loss: 0.7711 - val_acc: 0.5443
# Epoch 250/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5546 - acc: 0.7147 - val_loss: 0.7692 - val_acc: 0.5443
# Epoch 251/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5530 - acc: 0.7147 - val_loss: 0.7685 - val_acc: 0.5443
# Epoch 252/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5489 - acc: 0.7207 - val_loss: 0.7678 - val_acc: 0.5443
# Epoch 253/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5496 - acc: 0.7177 - val_loss: 0.7661 - val_acc: 0.5443
# Epoch 254/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5417 - acc: 0.7087 - val_loss: 0.7650 - val_acc: 0.5443
# Epoch 255/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5498 - acc: 0.7087 - val_loss: 0.7646 - val_acc: 0.5443
# Epoch 256/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5503 - acc: 0.7207 - val_loss: 0.7630 - val_acc: 0.5316
# Epoch 257/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5462 - acc: 0.7087 - val_loss: 0.7618 - val_acc: 0.5316
# Epoch 258/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5565 - acc: 0.6817 - val_loss: 0.7606 - val_acc: 0.5316
# Epoch 259/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5565 - acc: 0.7237 - val_loss: 0.7609 - val_acc: 0.5316
# Epoch 260/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5498 - acc: 0.7057 - val_loss: 0.7588 - val_acc: 0.5316
# Epoch 261/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5538 - acc: 0.7237 - val_loss: 0.7564 - val_acc: 0.5316
# Epoch 262/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5429 - acc: 0.7237 - val_loss: 0.7545 - val_acc: 0.5316
# Epoch 263/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5414 - acc: 0.7237 - val_loss: 0.7541 - val_acc: 0.5316
# Epoch 264/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5343 - acc: 0.7327 - val_loss: 0.7519 - val_acc: 0.5443
# Epoch 265/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5403 - acc: 0.7417 - val_loss: 0.7499 - val_acc: 0.5570
# Epoch 266/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5419 - acc: 0.7327 - val_loss: 0.7489 - val_acc: 0.5443
# Epoch 267/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5419 - acc: 0.7297 - val_loss: 0.7472 - val_acc: 0.5696
# Epoch 268/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5443 - acc: 0.7087 - val_loss: 0.7445 - val_acc: 0.5696
# Epoch 269/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5404 - acc: 0.7087 - val_loss: 0.7423 - val_acc: 0.5696
# Epoch 270/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5358 - acc: 0.7267 - val_loss: 0.7392 - val_acc: 0.5696
# Epoch 271/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5392 - acc: 0.7207 - val_loss: 0.7362 - val_acc: 0.5696
# Epoch 272/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5390 - acc: 0.7177 - val_loss: 0.7356 - val_acc: 0.5696
# Epoch 273/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5322 - acc: 0.7327 - val_loss: 0.7345 - val_acc: 0.5696
# Epoch 274/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5360 - acc: 0.7327 - val_loss: 0.7345 - val_acc: 0.5570
# Epoch 275/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5398 - acc: 0.7447 - val_loss: 0.7331 - val_acc: 0.5570
# Epoch 276/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5364 - acc: 0.7447 - val_loss: 0.7330 - val_acc: 0.5570
# Epoch 277/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5441 - acc: 0.7117 - val_loss: 0.7316 - val_acc: 0.5570
# Epoch 278/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5354 - acc: 0.7357 - val_loss: 0.7295 - val_acc: 0.5570
# Epoch 279/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5339 - acc: 0.7417 - val_loss: 0.7269 - val_acc: 0.5570
# Epoch 280/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5397 - acc: 0.7387 - val_loss: 0.7260 - val_acc: 0.5570
# Epoch 281/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5253 - acc: 0.7387 - val_loss: 0.7243 - val_acc: 0.5696
# Epoch 282/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5420 - acc: 0.7207 - val_loss: 0.7221 - val_acc: 0.5823
# Epoch 283/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5248 - acc: 0.7508 - val_loss: 0.7198 - val_acc: 0.5823
# Epoch 284/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5321 - acc: 0.7297 - val_loss: 0.7184 - val_acc: 0.5823
# Epoch 285/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5328 - acc: 0.7447 - val_loss: 0.7174 - val_acc: 0.5823
# Epoch 286/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5259 - acc: 0.7417 - val_loss: 0.7169 - val_acc: 0.5823
# Epoch 287/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5310 - acc: 0.7568 - val_loss: 0.7160 - val_acc: 0.5823
# Epoch 288/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5268 - acc: 0.7387 - val_loss: 0.7144 - val_acc: 0.5696
# Epoch 289/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5272 - acc: 0.7297 - val_loss: 0.7123 - val_acc: 0.5696
# Epoch 290/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5320 - acc: 0.7327 - val_loss: 0.7114 - val_acc: 0.5570
# Epoch 291/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5317 - acc: 0.7568 - val_loss: 0.7106 - val_acc: 0.5570
# Epoch 292/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5238 - acc: 0.7327 - val_loss: 0.7093 - val_acc: 0.5570
# Epoch 293/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5285 - acc: 0.7297 - val_loss: 0.7080 - val_acc: 0.5443
# Epoch 294/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5342 - acc: 0.7237 - val_loss: 0.7079 - val_acc: 0.5570
# Epoch 295/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5234 - acc: 0.7538 - val_loss: 0.7076 - val_acc: 0.5570
# Epoch 296/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5251 - acc: 0.7477 - val_loss: 0.7048 - val_acc: 0.5570
# Epoch 297/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5259 - acc: 0.7357 - val_loss: 0.7013 - val_acc: 0.5570
# Epoch 298/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5245 - acc: 0.7387 - val_loss: 0.6982 - val_acc: 0.5570
# Epoch 299/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5202 - acc: 0.7357 - val_loss: 0.6960 - val_acc: 0.5443
# Epoch 300/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5163 - acc: 0.7538 - val_loss: 0.6941 - val_acc: 0.5443
# Epoch 301/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5180 - acc: 0.7477 - val_loss: 0.6921 - val_acc: 0.5443
# Epoch 302/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5131 - acc: 0.7477 - val_loss: 0.6891 - val_acc: 0.5696
# Epoch 303/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5222 - acc: 0.7508 - val_loss: 0.6871 - val_acc: 0.5696
# Epoch 304/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5180 - acc: 0.7387 - val_loss: 0.6861 - val_acc: 0.5696
# Epoch 305/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5171 - acc: 0.7327 - val_loss: 0.6852 - val_acc: 0.5696
# Epoch 306/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5178 - acc: 0.7538 - val_loss: 0.6837 - val_acc: 0.5696
# Epoch 307/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5130 - acc: 0.7447 - val_loss: 0.6826 - val_acc: 0.5696
# Epoch 308/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5118 - acc: 0.7417 - val_loss: 0.6818 - val_acc: 0.5570
# Epoch 309/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5145 - acc: 0.7477 - val_loss: 0.6808 - val_acc: 0.5570
# Epoch 310/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5126 - acc: 0.7628 - val_loss: 0.6798 - val_acc: 0.5570
# Epoch 311/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5122 - acc: 0.7538 - val_loss: 0.6789 - val_acc: 0.5570
# Epoch 312/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5097 - acc: 0.7628 - val_loss: 0.6777 - val_acc: 0.5570
# Epoch 313/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5139 - acc: 0.7718 - val_loss: 0.6762 - val_acc: 0.5570
# Epoch 314/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5010 - acc: 0.7568 - val_loss: 0.6740 - val_acc: 0.5570
# Epoch 315/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5186 - acc: 0.7477 - val_loss: 0.6728 - val_acc: 0.5570
# Epoch 316/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5021 - acc: 0.7538 - val_loss: 0.6708 - val_acc: 0.5696
# Epoch 317/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5134 - acc: 0.7447 - val_loss: 0.6695 - val_acc: 0.5823
# Epoch 318/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5105 - acc: 0.7387 - val_loss: 0.6682 - val_acc: 0.5823
# Epoch 319/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5074 - acc: 0.7568 - val_loss: 0.6674 - val_acc: 0.5823
# Epoch 320/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5048 - acc: 0.7658 - val_loss: 0.6668 - val_acc: 0.5823
# Epoch 321/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4999 - acc: 0.7838 - val_loss: 0.6663 - val_acc: 0.5823
# Epoch 322/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5153 - acc: 0.7387 - val_loss: 0.6652 - val_acc: 0.5823
# Epoch 323/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5053 - acc: 0.7477 - val_loss: 0.6631 - val_acc: 0.5823
# Epoch 324/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5109 - acc: 0.7628 - val_loss: 0.6615 - val_acc: 0.5823
# Epoch 325/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5013 - acc: 0.7718 - val_loss: 0.6598 - val_acc: 0.5823
# Epoch 326/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5044 - acc: 0.7568 - val_loss: 0.6578 - val_acc: 0.5949
# Epoch 327/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4912 - acc: 0.7477 - val_loss: 0.6566 - val_acc: 0.6076
# Epoch 328/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5119 - acc: 0.7447 - val_loss: 0.6560 - val_acc: 0.6076
# Epoch 329/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5031 - acc: 0.7718 - val_loss: 0.6555 - val_acc: 0.6076
# Epoch 330/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5026 - acc: 0.7658 - val_loss: 0.6549 - val_acc: 0.6203
# Epoch 331/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5028 - acc: 0.7718 - val_loss: 0.6541 - val_acc: 0.6203
# Epoch 332/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4968 - acc: 0.7598 - val_loss: 0.6536 - val_acc: 0.6203
# Epoch 333/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4968 - acc: 0.7598 - val_loss: 0.6536 - val_acc: 0.6203
# Epoch 334/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4965 - acc: 0.7718 - val_loss: 0.6530 - val_acc: 0.6203
# Epoch 335/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4987 - acc: 0.7658 - val_loss: 0.6530 - val_acc: 0.6203
# Epoch 336/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4972 - acc: 0.7628 - val_loss: 0.6524 - val_acc: 0.6203
# Epoch 337/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4961 - acc: 0.7868 - val_loss: 0.6515 - val_acc: 0.6203
# Epoch 338/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5025 - acc: 0.7598 - val_loss: 0.6511 - val_acc: 0.6203
# Epoch 339/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4973 - acc: 0.7628 - val_loss: 0.6509 - val_acc: 0.6203
# Epoch 340/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5059 - acc: 0.7568 - val_loss: 0.6507 - val_acc: 0.6203
# Epoch 341/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5004 - acc: 0.7658 - val_loss: 0.6501 - val_acc: 0.6203
# Epoch 342/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4954 - acc: 0.7568 - val_loss: 0.6492 - val_acc: 0.6329
# Epoch 343/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4935 - acc: 0.7538 - val_loss: 0.6481 - val_acc: 0.6329
# Epoch 344/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4963 - acc: 0.7477 - val_loss: 0.6465 - val_acc: 0.6456
# Epoch 345/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5048 - acc: 0.7568 - val_loss: 0.6453 - val_acc: 0.6456
# Epoch 346/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4925 - acc: 0.7538 - val_loss: 0.6447 - val_acc: 0.6456
# Epoch 347/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4991 - acc: 0.7718 - val_loss: 0.6443 - val_acc: 0.6329
# Epoch 348/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.5002 - acc: 0.7568 - val_loss: 0.6441 - val_acc: 0.6329
# Epoch 349/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4959 - acc: 0.7688 - val_loss: 0.6439 - val_acc: 0.6329
# Epoch 350/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4976 - acc: 0.7628 - val_loss: 0.6436 - val_acc: 0.6329
# Epoch 351/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4903 - acc: 0.7688 - val_loss: 0.6434 - val_acc: 0.6329
# Epoch 352/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4859 - acc: 0.7928 - val_loss: 0.6429 - val_acc: 0.6329
# Epoch 353/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4921 - acc: 0.7778 - val_loss: 0.6428 - val_acc: 0.6329
# Epoch 354/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4847 - acc: 0.7838 - val_loss: 0.6428 - val_acc: 0.6203
# Epoch 355/500
# ...
# Epoch 383/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4824 - acc: 0.7868 - val_loss: 0.6250 - val_acc: 0.5949
# Epoch 384/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4753 - acc: 0.7778 - val_loss: 0.6242 - val_acc: 0.5949
# Epoch 385/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4789 - acc: 0.7748 - val_loss: 0.6230 - val_acc: 0.6076
# Epoch 386/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4774 - acc: 0.7868 - val_loss: 0.6220 - val_acc: 0.6076
# Epoch 387/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4766 - acc: 0.7898 - val_loss: 0.6216 - val_acc: 0.6076
# Epoch 388/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4792 - acc: 0.7658 - val_loss: 0.6213 - val_acc: 0.6203
# Epoch 389/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4742 - acc: 0.7868 - val_loss: 0.6214 - val_acc: 0.6329
# Epoch 390/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4808 - acc: 0.7718 - val_loss: 0.6209 - val_acc: 0.6329
# Epoch 391/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4894 - acc: 0.7538 - val_loss: 0.6208 - val_acc: 0.6329
# Epoch 392/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4814 - acc: 0.7838 - val_loss: 0.6206 - val_acc: 0.6456
# Epoch 393/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4717 - acc: 0.7748 - val_loss: 0.6198 - val_acc: 0.6329
# Epoch 394/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4776 - acc: 0.7778 - val_loss: 0.6196 - val_acc: 0.6076
# Epoch 395/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4710 - acc: 0.7778 - val_loss: 0.6191 - val_acc: 0.5949
# Epoch 396/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4729 - acc: 0.7778 - val_loss: 0.6185 - val_acc: 0.5949
# Epoch 397/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4730 - acc: 0.7868 - val_loss: 0.6182 - val_acc: 0.6076
# Epoch 398/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4664 - acc: 0.8048 - val_loss: 0.6173 - val_acc: 0.6076
# Epoch 399/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4684 - acc: 0.7958 - val_loss: 0.6169 - val_acc: 0.6203
# Epoch 400/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4709 - acc: 0.7958 - val_loss: 0.6167 - val_acc: 0.6203
# Epoch 401/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4773 - acc: 0.7898 - val_loss: 0.6166 - val_acc: 0.6203
# Epoch 402/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4731 - acc: 0.7808 - val_loss: 0.6167 - val_acc: 0.6076
# Epoch 403/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4770 - acc: 0.7808 - val_loss: 0.6165 - val_acc: 0.6203
# Epoch 404/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4722 - acc: 0.7898 - val_loss: 0.6158 - val_acc: 0.6076
# Epoch 405/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4882 - acc: 0.7658 - val_loss: 0.6158 - val_acc: 0.6076
# Epoch 406/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4768 - acc: 0.7838 - val_loss: 0.6146 - val_acc: 0.6203
# Epoch 407/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4775 - acc: 0.7658 - val_loss: 0.6138 - val_acc: 0.6329
# Epoch 408/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4752 - acc: 0.7928 - val_loss: 0.6138 - val_acc: 0.6203
# Epoch 409/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4805 - acc: 0.8048 - val_loss: 0.6135 - val_acc: 0.6203
# Epoch 410/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4751 - acc: 0.7868 - val_loss: 0.6136 - val_acc: 0.6329
# Epoch 411/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4808 - acc: 0.7718 - val_loss: 0.6133 - val_acc: 0.6329
# Epoch 412/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4720 - acc: 0.7778 - val_loss: 0.6133 - val_acc: 0.6203
# Epoch 413/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4693 - acc: 0.7838 - val_loss: 0.6134 - val_acc: 0.6203
# Epoch 414/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4703 - acc: 0.7898 - val_loss: 0.6138 - val_acc: 0.6329
# Epoch 415/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4708 - acc: 0.7838 - val_loss: 0.6136 - val_acc: 0.6329
# Epoch 416/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4766 - acc: 0.7868 - val_loss: 0.6137 - val_acc: 0.6329
# Epoch 417/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4665 - acc: 0.7958 - val_loss: 0.6141 - val_acc: 0.6329
# Epoch 418/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4658 - acc: 0.8048 - val_loss: 0.6144 - val_acc: 0.6203
# Epoch 419/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4735 - acc: 0.7628 - val_loss: 0.6148 - val_acc: 0.6203
# Epoch 420/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4616 - acc: 0.8048 - val_loss: 0.6150 - val_acc: 0.6203
# Epoch 421/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4717 - acc: 0.7928 - val_loss: 0.6150 - val_acc: 0.6203
# Epoch 422/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4582 - acc: 0.7988 - val_loss: 0.6150 - val_acc: 0.6203
# Epoch 423/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4705 - acc: 0.7898 - val_loss: 0.6147 - val_acc: 0.6203
# Epoch 424/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4734 - acc: 0.7778 - val_loss: 0.6139 - val_acc: 0.6203
# Epoch 425/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4643 - acc: 0.7928 - val_loss: 0.6135 - val_acc: 0.6203
# Epoch 426/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4787 - acc: 0.7898 - val_loss: 0.6132 - val_acc: 0.6329
# Epoch 427/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4667 - acc: 0.7928 - val_loss: 0.6133 - val_acc: 0.6203
# Epoch 428/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4648 - acc: 0.7988 - val_loss: 0.6133 - val_acc: 0.6203
# Epoch 429/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4678 - acc: 0.7868 - val_loss: 0.6134 - val_acc: 0.6329
# Epoch 430/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4592 - acc: 0.7928 - val_loss: 0.6137 - val_acc: 0.6329
# Epoch 431/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4674 - acc: 0.7808 - val_loss: 0.6133 - val_acc: 0.6203
# Epoch 432/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4641 - acc: 0.7928 - val_loss: 0.6131 - val_acc: 0.6203
# Epoch 433/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4645 - acc: 0.7898 - val_loss: 0.6129 - val_acc: 0.6203
# Epoch 434/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4648 - acc: 0.7898 - val_loss: 0.6125 - val_acc: 0.6203
# Epoch 435/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4652 - acc: 0.7778 - val_loss: 0.6127 - val_acc: 0.6329
# Epoch 436/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4655 - acc: 0.7988 - val_loss: 0.6125 - val_acc: 0.6329
# Epoch 437/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4683 - acc: 0.7958 - val_loss: 0.6122 - val_acc: 0.6203
# Epoch 438/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4605 - acc: 0.7898 - val_loss: 0.6122 - val_acc: 0.6329
# Epoch 439/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4738 - acc: 0.7898 - val_loss: 0.6124 - val_acc: 0.6456
# Epoch 440/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4608 - acc: 0.7928 - val_loss: 0.6123 - val_acc: 0.6456
# Epoch 441/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4570 - acc: 0.7898 - val_loss: 0.6122 - val_acc: 0.6456
# Epoch 442/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4683 - acc: 0.7838 - val_loss: 0.6122 - val_acc: 0.6456
# Epoch 443/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4662 - acc: 0.7868 - val_loss: 0.6121 - val_acc: 0.6456
# Epoch 444/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4563 - acc: 0.7958 - val_loss: 0.6121 - val_acc: 0.6456
# Epoch 445/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4597 - acc: 0.7958 - val_loss: 0.6118 - val_acc: 0.6456
# Epoch 446/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4541 - acc: 0.8138 - val_loss: 0.6118 - val_acc: 0.6456
# Epoch 447/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4542 - acc: 0.8168 - val_loss: 0.6117 - val_acc: 0.6456
# Epoch 448/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4581 - acc: 0.7958 - val_loss: 0.6115 - val_acc: 0.6456
# Epoch 449/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4565 - acc: 0.8108 - val_loss: 0.6111 - val_acc: 0.6456
# Epoch 450/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4571 - acc: 0.8048 - val_loss: 0.6109 - val_acc: 0.6456
# Epoch 451/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4702 - acc: 0.8018 - val_loss: 0.6108 - val_acc: 0.6456
# Epoch 452/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4579 - acc: 0.7988 - val_loss: 0.6111 - val_acc: 0.6456
# Epoch 453/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4593 - acc: 0.8078 - val_loss: 0.6109 - val_acc: 0.6456
# Epoch 454/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4576 - acc: 0.8048 - val_loss: 0.6113 - val_acc: 0.6456
# Epoch 455/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4557 - acc: 0.8258 - val_loss: 0.6111 - val_acc: 0.6456
# Epoch 456/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4599 - acc: 0.7958 - val_loss: 0.6117 - val_acc: 0.6456
# Epoch 457/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4572 - acc: 0.8018 - val_loss: 0.6118 - val_acc: 0.6456
# Epoch 458/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4507 - acc: 0.8018 - val_loss: 0.6123 - val_acc: 0.6456
# Epoch 459/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4564 - acc: 0.8048 - val_loss: 0.6128 - val_acc: 0.6456
# Epoch 460/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4635 - acc: 0.7838 - val_loss: 0.6132 - val_acc: 0.6456
# Epoch 461/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4603 - acc: 0.8048 - val_loss: 0.6130 - val_acc: 0.6456
# Epoch 462/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4571 - acc: 0.7928 - val_loss: 0.6129 - val_acc: 0.6456
# Epoch 463/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4563 - acc: 0.7928 - val_loss: 0.6132 - val_acc: 0.6456
# Epoch 464/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4696 - acc: 0.7958 - val_loss: 0.6132 - val_acc: 0.6456
# Epoch 465/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4557 - acc: 0.7958 - val_loss: 0.6136 - val_acc: 0.6582
# Epoch 466/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4557 - acc: 0.7988 - val_loss: 0.6138 - val_acc: 0.6582
# Epoch 467/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4577 - acc: 0.7778 - val_loss: 0.6139 - val_acc: 0.6582
# Epoch 468/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4532 - acc: 0.8168 - val_loss: 0.6141 - val_acc: 0.6582
# Epoch 469/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4586 - acc: 0.7988 - val_loss: 0.6144 - val_acc: 0.6582
# Epoch 470/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4518 - acc: 0.7988 - val_loss: 0.6151 - val_acc: 0.6456
# Epoch 471/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4621 - acc: 0.7898 - val_loss: 0.6157 - val_acc: 0.6456
# Epoch 472/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4557 - acc: 0.7928 - val_loss: 0.6157 - val_acc: 0.6582
# Epoch 473/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4539 - acc: 0.8138 - val_loss: 0.6161 - val_acc: 0.6456
# Epoch 474/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4539 - acc: 0.8198 - val_loss: 0.6163 - val_acc: 0.6456
# Epoch 475/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4616 - acc: 0.7988 - val_loss: 0.6163 - val_acc: 0.6456
# Epoch 476/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4592 - acc: 0.8018 - val_loss: 0.6169 - val_acc: 0.6329
# Epoch 477/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4552 - acc: 0.8048 - val_loss: 0.6169 - val_acc: 0.6329
# Epoch 478/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4475 - acc: 0.8048 - val_loss: 0.6168 - val_acc: 0.6329
# Epoch 479/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4505 - acc: 0.8078 - val_loss: 0.6164 - val_acc: 0.6329
# Epoch 480/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4477 - acc: 0.8078 - val_loss: 0.6160 - val_acc: 0.6329
# Epoch 481/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4527 - acc: 0.8108 - val_loss: 0.6153 - val_acc: 0.6329
# Epoch 482/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4602 - acc: 0.8048 - val_loss: 0.6145 - val_acc: 0.6582
# Epoch 483/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4617 - acc: 0.7988 - val_loss: 0.6139 - val_acc: 0.6456
# Epoch 484/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4592 - acc: 0.7958 - val_loss: 0.6143 - val_acc: 0.6582
# Epoch 485/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4522 - acc: 0.8168 - val_loss: 0.6143 - val_acc: 0.6456
# Epoch 486/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4570 - acc: 0.7838 - val_loss: 0.6141 - val_acc: 0.6329
# Epoch 487/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4519 - acc: 0.8108 - val_loss: 0.6145 - val_acc: 0.6329
# Epoch 488/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4466 - acc: 0.8018 - val_loss: 0.6138 - val_acc: 0.6329
# Epoch 489/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4543 - acc: 0.7988 - val_loss: 0.6142 - val_acc: 0.6329
# Epoch 490/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4502 - acc: 0.8078 - val_loss: 0.6147 - val_acc: 0.6329
# Epoch 491/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4437 - acc: 0.8138 - val_loss: 0.6162 - val_acc: 0.6203
# Epoch 492/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4546 - acc: 0.7808 - val_loss: 0.6180 - val_acc: 0.6203
# Epoch 493/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4504 - acc: 0.8048 - val_loss: 0.6188 - val_acc: 0.6203
# Epoch 494/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4462 - acc: 0.8018 - val_loss: 0.6190 - val_acc: 0.6203
# Epoch 495/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4498 - acc: 0.8018 - val_loss: 0.6190 - val_acc: 0.6203
# Epoch 496/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4421 - acc: 0.8108 - val_loss: 0.6194 - val_acc: 0.6203
# Epoch 497/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4438 - acc: 0.8108 - val_loss: 0.6195 - val_acc: 0.6203
# Epoch 498/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4413 - acc: 0.8078 - val_loss: 0.6187 - val_acc: 0.6203
# Epoch 499/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4547 - acc: 0.8138 - val_loss: 0.6181 - val_acc: 0.6203
# Epoch 500/500
# 333/333 [==============================] - 1s 4ms/step - loss: 0.4421 - acc: 0.8198 - val_loss: 0.6174 - val_acc: 0.6329

# %% [markdown]
# ### Step 6: Plot the training history
# We can view the training history of the model by plotting the performance (value of the loss function) for training and validation data in each epoch.

# %%
##### Step 6: plot train and validation loss #####
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Step 7: Evaluate the performance using test data
# We load the final model from a save file (Final_weights.hdf5) for the following analysis steps. We will use the test data, which has not been touched so far, to evaluate the performance of the final model. We will draw a Receiver Operator Characteristic(ROC) Curve and use Area Under the Curve (AUC) to measure performance.

# %%
##### Step 7: test the final model #####

# load final model
final_model = load_model('Data/Final_weights.hdf5')

# generate ROC and AUC
y_scores = final_model.predict([x_test])
fpr, tpr, _ = roc_curve(y_test, y_scores)
roc_auc = auc(fpr, tpr)

# plot ROC curve
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC = {0:.2f}'.format(roc_auc))
plt.show()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# ### Step 8: Interpret the deep learning model.
# We will use a permutation-based method to interpret the deep CNN model (Fig. 2). For each cell in cytometry data, we up-sampled the cell by copying it to replace other randomly chosen cells within the sample. We then applied the deep CNN model on both the original data and the permuted data. The difference in the model output (ΔΥ) quantifies the impact of the cell on the output of the deep learning model. Finally, we build a decision tree model to idenitfy cell subsets that have the highest ΔΥ.
#
# ![alt text](Data/Figure2.png)

# %%
##### Step 8: Interpret the deep learning model. #####

# warning: may take a long time (around 30 mins) to run

# Calculate the impact of each cell on the model output
dY = np.zeros([x_test.shape[0],x_test.shape[1]])
s1 = np.random.randint(0,(x_test.shape[1]-1),int(x_test.shape[1]*0.05))

for i in range(x_test.shape[0]):
    pred_i = final_model.predict([x_test[[i],:,:,:]])
    for j in range(x_test.shape[1]):
        t1 = x_test[[i],:,:,:].copy()
        t1[:,s1,:,:] = t1[:,j,:,:]
        pred_j = final_model.predict([t1])
        dY[i,j] = pred_j-pred_i

# reformat dY
x_test2 = x_test.reshape((x_test.shape[0]*x_test.shape[1],27))
dY = dY.reshape([x_test.shape[0]*x_test.shape[1]])

# Build decision tree to identify cell subset with high dY
regr_1 = DecisionTreeRegressor(max_depth=4)
regr_1.fit(x_test2, dY)

# Plot the decision tree
dot_data = StringIO()
export_graphviz(regr_1, out_file=dot_data, 
                feature_names= markerNames,
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ### Conclusion
# In this tutorial, we build a deep convolutional neural network (CNN) to analyze CyTOF data. The deep CNN model is able to diagnose latent CMV infection with high accuracy. In addition, we were able to interpret the deep learning model using a permutation-based method. We discovered that a CD3+ CD8+ CD27- CD94+ population that have the highest impact on the deep CNN model.
